# %%
import pandas as pd
melbourne_houses = pd.read_csv('melb_data.csv')

# %%
melbourne_houses.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
melbourne_houses['Method'].value_counts()
# Out:
# S     9022
# SP    1703
# PI    1564
# VB    1199
# SA      92
# Name: Method, dtype: int64

# %%
suburb_count = melbourne_houses['Suburb'].value_counts()

# %%
suburb_count.describe()
# Out:
# count    314.000000
# mean      43.248408
# std       55.138994
# min        1.000000
# 25%        6.250000
# 50%       20.500000
# 75%       59.000000
# max      359.000000
# Name: Suburb, dtype: float64

# %%
melb_house_df = melbourne_houses.copy()

# %%
melb_house_df.loc[melb_house_df['Suburb'] == 'Brighton']
# Out:
#          Suburb           Address  Rooms Type      Price Method   SellerG  \
# 1040   Brighton    802 Hampton St      3    h  1550000.0     VB    Buxton
# 1041   Brighton     18 Rooding St      3    h  1635000.0      S    Buxton
# 1042   Brighton  152A Cochrane St      4    h  1830000.0      S    Hodges
# 1043   Brighton    17 McCallum St      4    h  3695000.0      S  Marshall
# 1044   Brighton   2/26 Pearson St      2    u   536000.0     SP    Hodges
# ...         ...               ...    ...  ...        ...    ...       ...
# 12915  Brighton   2A Hillcrest Av      4    h  1850000.0     VB    Jellis
# 12916  Brighton      34 Moffat St      4    h  2770000.0      S      Nick
# 13366  Brighton      3 Adamson St      4    h  3200000.0     VB  Marshall
# 13367  Brighton      53 Elwood St      4    h  2830000.0      S      Nick
# 13368  Brighton        44 Meek St      4    h  2260000.0      S      Nick
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
melb_house_df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
melb_house_df.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
melb_house_df.drop(columns = ['Address','Type','Method','SellerG','Date','CouncilArea','Regionname','Postcode','Lattitude','Longtitude','Propertycount'], inplace = True)

# %%
melb_house_df.dtypes
# Out:
# Suburb           object
# Rooms             int64
# Price           float64
# Distance        float64
# Bedroom2        float64
# Bathroom        float64
# Car             float64
# Landsize        float64
# BuildingArea    float64
# YearBuilt       float64
# dtype: object

# %%
#this checks which columns have null values
melb_house_df.columns[melb_house_df.isnull().any()].tolist()
# Out:
# ['Car', 'BuildingArea', 'YearBuilt']

# %%
#this shows only the rows that have null values 
melb_house_df[melb_house_df.isnull().any(axis=1)]
# Out:
#                Suburb  Rooms      Price  Distance  Bedroom2  Bathroom  Car  \
# 0          Abbotsford      2  1480000.0       2.5       2.0       1.0  1.0
# 3          Abbotsford      3   850000.0       2.5       3.0       2.0  1.0
# 5          Abbotsford      2   941000.0       2.5       2.0       1.0  0.0
# 8          Abbotsford      1   300000.0       2.5       1.0       1.0  1.0
# 10         Abbotsford      2   700000.0       2.5       2.0       2.0  1.0
# ...               ...    ...        ...       ...       ...       ...  ...
# 13569  Wantirna South      4  1323000.0      14.7       4.0       2.0  2.0
# 13570  Wantirna South      3   970000.0      14.7       3.0       2.0  2.0
# 13574     Westmeadows      3   582000.0      16.5       3.0       2.0  2.0
# 13575   Wheelers Hill      4  1245000.0      16.7       4.0       2.0  2.0
# 13577    Williamstown      3  1170000.0       6.8       3.0       2.0  4.0
#
#        Landsize  BuildingArea  YearBuilt
# ...

# %%
#fills all the null values with zero!!!
melb_house_df.fillna(0, inplace = True)

# %%
melb_house_df.head()
# Out:
#        Suburb  Rooms      Price  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0  Abbotsford      2  1480000.0       2.5       2.0       1.0  1.0     202.0
# 1  Abbotsford      2  1035000.0       2.5       2.0       1.0  0.0     156.0
# 2  Abbotsford      3  1465000.0       2.5       3.0       2.0  0.0     134.0
# 3  Abbotsford      3   850000.0       2.5       3.0       2.0  1.0      94.0
# 4  Abbotsford      4  1600000.0       2.5       3.0       1.0  2.0     120.0
#
#    BuildingArea  YearBuilt
# 0           0.0        0.0
# 1          79.0     1900.0
# 2         150.0     1900.0
# 3           0.0        0.0
# 4         142.0     2014.0

# %%
melb_house_df.corr()
# Out:
#                  Rooms     Price  Distance  Bedroom2  Bathroom       Car  \
# Rooms         1.000000  0.496634  0.294203  0.944190  0.592934  0.408364
# Price         0.496634  1.000000 -0.162522  0.475951  0.467038  0.234825
# Distance      0.294203 -0.162522  1.000000  0.295927  0.127155  0.266082
# Bedroom2      0.944190  0.475951  0.295927  1.000000  0.584685  0.405046
# Bathroom      0.592934  0.467038  0.127155  0.584685  1.000000  0.322434
# Car           0.408364  0.234825  0.266082  0.405046  0.322434  1.000000
# Landsize      0.025678  0.037507  0.025004  0.025646  0.037130  0.026463
# BuildingArea  0.097950  0.069627  0.072750  0.094906  0.101881  0.067463
# YearBuilt    -0.005392 -0.027001 -0.021075 -0.005679  0.076008 -0.020529
#
#               Landsize  BuildingArea  YearBuilt
# Rooms         0.025678      0.097950  -0.005392
# Price         0.037507      0.069627  -0.027001
# Distance      0.025004      0.072750  -0.021075
# ...
